# %%
pip install geopandas
# Out:
# ...
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/27/27/2687abaa2ac02b5814e2929a5033da1e5d132c19a904dc56f77f63fd6eb9/geopandas-0.14.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/92/da/8dd3d9e9061e90ebe7d173d47547e937a282a8a8d4a4a10c4e7193011536/Fiona-1.9.4.post1-cp39-cp39-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.6 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.6 kB ? eta -:--:--
#      ----------------------- -------------- 30.7/50.6 kB 220.2 kB/s eta 0:00:01
#      ------------------------------ ------- 41.0/50.6 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 50.6/50.6 kB 288.6 kB/s eta 0:00:00
# ...

# %%
import geopandas as gpd

# Provide the path to your GeoPackage file
gpkg_file_path = "/Users/gdvdb/Documents/Master AES/AESM/AESM5/ASG/liander_elektriciteitsnetten.gpkg"

# Read the GeoPackage file into a GeoDataFrame
gdf = gpd.read_file(gpkg_file_path)

# %%
# Display the first few rows of the GeoDataFrame
print(gdf.head())

# Plot the data
gdf.plot()

# Perform spatial queries, filtering, and other geospatial operations
# Out:
#               id                                           geometry
# 0  1099513496563  LINESTRING (118691.411 527129.167, 118691.503 ...
# 1  1099513496585  LINESTRING (118691.429 527129.126, 118691.535 ...
# 2  1099513496625  LINESTRING (118691.442 527129.090, 118691.578 ...
# 3  1099513496636  LINESTRING (118692.432 527127.076, 118692.484 ...
# 4  1099513496658  LINESTRING (118692.450 527126.978, 118692.527 ...
# <Axes: >

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Provide the paths to your GeoPackage files
netherlands_gpkg_path = "/Users/gdvdb/Documents/Master AES/AESM/AESM5/ASG/gadm41_NLD.gpkg" 

# Read the GeoPackage files into GeoDataFrames
netherlands_gdf = gpd.read_file(netherlands_gpkg_path)
print(netherlands_gdf.head)

# Create a plot
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the Netherlands outline
netherlands_gdf.boundary.plot(ax=ax, color='black', linewidth=1)

# Plot your data (replace this with your data)
# gdf.plot(ax=ax, color='blue', markersize=5)

# Add labels, titles, legends, etc., as needed
plt.title("Netherlands Outline with Your Data")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# Show the plot
plt.show()
# Out:
# <bound method NDFrame.head of   GID_0      COUNTRY                                           geometry
# 0   NLD  Netherlands  MULTIPOLYGON (((6.00713 50.75663, 6.00707 50.7...>

# %%
gml_file_path = "/Users/gdvdb/Documents/Master AES/AESM/AESM5/ASG/inspire-pv-ps.nlps-nnn.gml"

# Read the GML file into a GeoDataFrame
green = gpd.read_file(gml_file_path)

green.plot(cmap='Greens')
# Out:
# <Axes: >
